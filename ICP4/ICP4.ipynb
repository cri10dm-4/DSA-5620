# %% [markdown]
# <a href="https://colab.research.google.com/github/cri10dm-4/DSA-5620/blob/main/ICP4/ICP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **1.**

# %%
# Creating a DataFrame from a given dictionary
data = {
    'ID': np.arange(1, 1000001),  # 1 million IDs (from 1 to 1,000,000)
    'Value': np.random.rand(1000000),  # 1 million random float values between 0 and 1
    'Category': np.random.choice(['A', 'B', 'C', 'D'], size=1000000)  # 1 million random categories (A, B, C, D)
}
df = pd.DataFrame(data)

# %% [markdown]
# # **2.**

# %%
# Output first 10 rows
df.head(10)
# Out:
#    ID     Value Category
# 0   1  0.997705        B
# 1   2  0.564831        B
# 2   3  0.339902        A
# 3   4  0.705144        A
# 4   5  0.110736        C
# 5   6  0.871655        B
# 6   7  0.783012        C
# 7   8  0.436180        C
# 8   9  0.433135        B
# 9  10  0.240183        C

# %% [markdown]
# # **3.**

# %%
# Access a column “Value”
df['Value'].head()
# Out:
# 0    0.997705
# 1    0.564831
# 2    0.339902
# 3    0.705144
# 4    0.110736
# Name: Value, dtype: float64

# %% [markdown]
# # **4.**

# %%
# Modify columns in the DataFrame with names (ID number, Random value, Choice) and show output for first five rows.
df.columns = ['ID No', 'ID Value', 'ID Category']
# df = df.rename(columns={'ID': 'ID number','Value': 'Random value','Category': 'Choice'})
df.head(5)
# Out:
#    ID No  ID Value ID Category
# 0      1  0.997705           B
# 1      2  0.564831           B
# 2      3  0.339902           A
# 3      4  0.705144           A
# 4      5  0.110736           C

# %% [markdown]
# # **5.**

# %%
# Run the below given code by removing bugs and errors.

"""
import pandas as pd
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'V', 'VI', VI, 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_birth': ['15/05/2002', '17/05/2002', '16/02/1999', '25/09/1998', '11/05/2002', '15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 21],
    'address' ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
print("Original DataFrame:")
print(student_data)
print("\nSplit the said data on school_code, class wise:")
result = student.groupby(['school_code', 'class'])
for name, group in result:
    print("\nGroup:")
    print(name)
    print(group)
"""
import pandas as pd
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'], ################################################################# Solved for bug -- NameError: name 'VI' is not defined
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_birth': ['15/05/2002', '17/05/2002', '16/02/1999', '25/09/1998', '11/05/2002', '15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 21],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']}, ################################## Solved for bug -- ':' expected after dictionary key
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
print("Original DataFrame:")
print(student_data)
print("\nSplit the said data on school_code, class wise:")
result = student_data.groupby(['school_code', 'class']) ################################## Solved for bug -- NameError: name 'student' is not defined
for name, group in result:
    print("\nGroup:")
    print(name)
    print(group)
# Out:
# Original DataFrame:
#    school_code class            name date_of_birth  age  height  weight  \
# S1        s001     V  Alberto Franco    15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill    17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes    16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton    25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill    11/05/2002   14     151      31
# S6        s004    VI    David Parkes    15/09/1997   12     159      21
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4
#
# Split the said data on school_code, class wise:
#
# Group:
# ('s001', 'V')
#    school_code class            name date_of_birth  age  height  weight  \
# S1        s001     V  Alberto Franco    15/05/2002   12     173      35
#
#     address
# S1  street1
#
# Group:
# ('s001', 'VI')
# ...

# %% [markdown]
# # **6.**

# %%
# Read the provided CSV file ‘data.csv’.
# https://drive.google.com/drive/folders/1h8C3mLsso-R-sIOLsvoYwPLzy2fJ4IOF?usp=sharing
# https://drive.google.com/file/d/1-Ir3AXK1A77A-qCDu5gGkAxv-nbmWlHO/view?usp=drive_link
# df = pd.read_csv('https://drive.google.com/file/d/1-Ir3AXK1A77A-qCDu5gGkAxv-nbmWlHO/view?usp=drive_link')
# df = pd.read_csv('https://drive.google.com/drive/folders/1h8C3mLsso-R-sIOLsvoYwPLzy2fJ4IOF?usp=sharing', on_bad_lines='skip')
df = pd.read_csv('/content/drive/My Drive/DSA-5620/ICP4/data/data.csv')
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# # **7.**

# %%
# Show the basic statistical description about the data.
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# # **8.**

# %%
# Check if the data has null values.
# df.isnull().sum()
df[df.isnull().any(axis=1)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
# Replace the null values with the mean
df = df.fillna(df.mean())
df.loc[[17, 27, 91, 118, 141]]
# Out:
#      Duration  Pulse  Maxpulse    Calories
# 17         45     90       112  375.790244
# 27         60    103       132  375.790244
# 91         45    107       137  375.790244
# 118        60    105       125  375.790244
# 141        60     97       127  375.790244

# %% [markdown]
# # **9.**

# %%
# Select at least two columns and aggregate the data using: min, max, count, mean.
aggregates = df[['Calories', 'Pulse']].agg(['min', 'max', 'count', 'mean'])
aggregates
# Out:
#           Calories       Pulse
# min      50.300000   80.000000
# max    1860.400000  159.000000
# count   169.000000  169.000000
# mean    375.790244  107.461538

# %% [markdown]
# # **10.**

# %%
# Filter the dataframe to select the rows with calories values between 500 and 1000.
df_Cal_500_1000 = df[(df['Calories'] >= 500) & (df['Calories'] <= 1000)]
df_Cal_500_1000
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# # **11.**

# %%
# Filter the dataframe to select the rows with calories values > 500 and pulse < 100.
df_Cal_Pulse_Fltr = df[(df['Calories'] > 500) & (df['Pulse'] < 100)]
df_Cal_Pulse_Fltr
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# # **12.**

# %%
# Create a new “df_modified” dataframe that contains all the columns from df except for “Maxpulse”.
df_modified = df.drop(columns=['Maxpulse'])
df_modified.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %% [markdown]
# # **13.**

# %%
# Delete the “Maxpulse” column from the main df dataframe
df.drop(columns=['Maxpulse'], inplace=True)
df.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %% [markdown]
# # **14.**

# %%
# Convert the datatype of Calories column to int datatype.
df.info()
df['Calories'] = df['Calories'].astype(int)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Calories  169 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 4.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Calories  169 non-null    int64
# dtypes: int64(3)
# memory usage: 4.1 KB
#    Duration  Pulse  Calories
# 0        60    110       409
# 1        60    117       479
# 2        60    103       340
# 3        45    109       282
# 4        45    117       406

# %% [markdown]
# # **15.**

# %%
# Using pandas create a scatter plot for the two columns (Duration and Calories).
df.plot.scatter(x='Duration', y='Calories', title="Duration vs Calories")
# Out:
# <Axes: title={'center': 'Duration vs Calories'}, xlabel='Duration', ylabel='Calories'>
